# %%
import pandas as pd
from pandas import DataFrame
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="ticks", color_codes=True)

#ReadExcel = pd.read_excel (r'HEB_data.xlsx') 
#ReadExcel.rename(columns={'Linguistic SL':'Percent Correct'}, inplace=True)
#ReadExcel=pd.DataFrame(ReadExcel, columns=['Subject','Language','Gender','Age','Vocabulary','Author Task','Overall English Likeness','SL','Percent Correct','Overall English Likeness', 'Q1','Q2','Q3','Q4','Q5','Average English Likeness']) #use xls for earlier versions of excel
#print (ReadExcel)

df = pd.read_excel('/Users/julieschneider/Julie_Personal/Projects/HEB/HEB_data.xlsx', sheet_name='Sheet1')
df.rename(columns={'Linguistic SL':'Percent Correct'}, inplace=True)
df.rename(columns={'SL':'Statistical Learning'}, inplace=True)

print("Column headings:")
print(df.columns)
print(df)
# Out:
# Column headings:
# Index(['Subject', 'Language', 'Gender', 'Age', 'Vocabulary', 'Author Task',
#        'Overall English Likeness', 'Statistical Learning', 'Percent Correct',
#        'Overall English Likeness.1', 'Q1', 'Q2', 'Q3', 'Q4', 'Q5',
#        'Average English Likeness'],
#       dtype='object')
#     Subject Language  Gender  Age  Vocabulary  Author Task  \
# 0     a_001  English  Female   21       102.0          NaN
# 1     a_002  English  Female   19        98.0         -9.0
# 2     a_003  English    Male   19        92.0         -4.0
# 3     a_004  English  Female   19       115.0         12.0
# 4     a_005  English  Female   21       102.0         19.0
# 5     a_006  English  Female   21       102.0         14.0
# 6     a_007  English    Male   19       133.0          4.0
# 7     a_008  English  Female   21        96.0          8.0
# 8     a_009  English  Female   20       114.0          3.0
# 9     a_010  English  Female   20       103.0          1.0
# ...

# %%
#sns.load_dataset("HEB_data")
sns.catplot(x="Statistical Learning", y="Percent Correct", hue="Language", kind="bar", data=df);
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.catplot(x="Language", y="Percent Correct", hue="Statistical Learning", kind="violin", inner="stick", split=True, data=df);

# %%
sns.catplot(x="Statistical Learning", y="Percent Correct", hue="Language", kind="box", data=df);

# %%
#df.loc[df['SL'] == 'Linguistic']
#sns.lmplot(x="Vocabulary", y="Percent Correct", col="Statistical Learning", data=df);
sns.lmplot(x="Vocabulary", y="Percent Correct", hue="Statistical Learning", data=df);
sns.lmplot(x="Author Task", y="Percent Correct", hue="Statistical Learning", data=df);
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

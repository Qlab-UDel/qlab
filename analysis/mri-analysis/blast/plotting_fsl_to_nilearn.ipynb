# %% [markdown]
# This script plots FSL output onto NiLearn Glass Brain

# %%
from nilearn import datasets
from nilearn.image import smooth_img


TSL_result_img = smooth_img('/Volumes/data/projects/blast/data/derivatives/fsl/higherlevelanalysis/ASL_pc.gfeat/cope1.feat/stats/zstat1.nii.gz', fwhm=6)  
SSL_result_img = smooth_img('/Volumes/data/projects/blast/data/derivatives/fsl/higherlevelanalysis/ASL_pc.gfeat/cope2.feat/stats/zstat2.nii.gz', fwhm=6)
#VSL_result_img = smooth_img('/Volumes/data/projects/blast/data/derivatives/fsl/higherlevelanalysis/sub-blastc210/VSL_norm.gfeat/cope1.feat/stats/zstat1.nii.gz', fwhm=6) 
#LSL_result_img = smooth_img('/Volumes/data/projects/blast/data/derivatives/fsl/higherlevelanalysis/sub-blastc210/VSL_norm.gfeat/cope2.feat/stats/zstat2.nii.gz', fwhm=6)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py:219: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#   return f(*args, **kwds)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/nilearn/datasets/neurovault.py:16: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Container
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-aab000c55d7a> in <module>()
#       3
#       4
# ----> 5 TSL_result_img = smooth_img('/Volumes/data/projects/blast/data/derivatives/fsl/higherlevelanalysis/ASL_pc.gfeat/cope1.feat/stats/zstat1.nii.gz', fwhm=6)
#       6 SSL_result_img = smooth_img('/Volumes/data/projects/blast/data/derivatives/fsl/higherlevelanalysis/ASL_pc.gfeat/cope2.feat/stats/zstat2.nii.gz', fwhm=6)
#       7 #VSL_result_img = smooth_img('/Volumes/data/projects/blast/data/derivatives/fsl/higherlevelanalysis/sub-blastc210/VSL_norm.gfeat/cope1.feat/stats/zstat1.nii.gz', fwhm=6)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/nilearn/image/image.py in smooth_img(imgs, fwhm)
#     265     ret = []
#     266     for img in imgs:
# --> 267         img = check_niimg(img)
#     268         affine = img.affine
#     269         filtered = _smooth_array(img.get_data(), affine, fwhm=fwhm,
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/nilearn/_utils/niimg_conversions.py in check_niimg(niimg, ensure_ndim, atleast_4d, dtype, return_iterator, wildcards)
#     257                 raise ValueError(message)
#     258             else:
# --> 259                 raise ValueError("File not found: '%s'" % niimg)
#     260         elif not os.path.exists(niimg):
#     261             raise ValueError("File not found: '%s'" % niimg)
#
# ValueError: File not found: '/Volumes/data/projects/blast/data/derivatives/fsl/higherlevelanalysis/ASL_pc.gfeat/cope1.feat/stats/zstat1.nii.gz'

# %%
from nilearn import plotting

#plotting.plot_glass_brain(result_img, title='plot_glass_brain',
#                          threshold=3)

plotting.plot_glass_brain(SSL_result_img, title='Speech Structure v Random', threshold = 'auto')
plotting.plot_glass_brain(TSL_result_img, title='Tone Structure v Random', threshold = 'auto')
plotting.plot_glass_brain(LSL_result_img, title='Letter Structure v Random', threshold = 'auto')
plotting.plot_glass_brain(VSL_result_img, title='Image Structure v Random', threshold = 'auto')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/colors.py:53: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Sized
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py:219: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#   return f(*args, **kwds)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/nilearn/plotting/displays.py:600: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   if isinstance(axes, collections.Sequence):
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:2347: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   if isinstance(obj, collections.Iterator):
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/scipy/ndimage/measurements.py:272: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return _nd_image.find_objects(input, max_label)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/numpy/lib/type_check.py:546: DeprecationWarning: np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead
#   'a.item() instead', DeprecationWarning, stacklevel=1)

# %%
plotting.plot_glass_brain(SSL_result_img, title='Speech Structure v Random', threshold = 2.3)
plotting.plot_glass_brain(TSL_result_img, title='Tone Structure v Random', threshold = 2.3)
plotting.plot_glass_brain(LSL_result_img, title='Letter Structure v Random', threshold = 2.3)
plotting.plot_glass_brain(VSL_result_img, title='Image Structure v Random', threshold = 2.3)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/scipy/ndimage/measurements.py:272: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return _nd_image.find_objects(input, max_label)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/numpy/lib/type_check.py:546: DeprecationWarning: np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead
#   'a.item() instead', DeprecationWarning, stacklevel=1)

# %%
plotting.plot_glass_brain(SSL_result_img, title='Speech Structure v Random', black_bg=True, display_mode='lyrz', threshold='auto')
plotting.plot_glass_brain(TSL_result_img, title='Tone Structure v Random', black_bg=True, display_mode='lyrz', threshold='auto')
plotting.plot_glass_brain(LSL_result_img, title='Letter Structure v Random', black_bg=True, display_mode='lyrz', threshold='auto')
plotting.plot_glass_brain(VSL_result_img, title='Image Structure v Random', black_bg=True, display_mode='lyrz', threshold='auto')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/scipy/ndimage/measurements.py:272: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return _nd_image.find_objects(input, max_label)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/numpy/lib/type_check.py:546: DeprecationWarning: np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead
#   'a.item() instead', DeprecationWarning, stacklevel=1)

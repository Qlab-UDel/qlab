# %%
from nilearn import datasets
from nilearn.image import smooth_img


TSL_struct_result_img = smooth_img('/Users/qigroup/mnt/sylvian/blast/data/derivatives/fsl/grouplevelanalysis/TSL_child_JOVE_3.09_masked.gfeat/cope1.feat/cluster_mask_zstat1.nii.gz', fwhm=6)  
TSL_rand_result_img = smooth_img('/Users/qigroup/mnt/sylvian/blast/data/derivatives/fsl/grouplevelanalysis/TSL_child_JOVE_3.09_masked.gfeat/cope2.feat/cluster_mask_zstat1.nii.gz', fwhm=6)  


SSL_struct_result_img = smooth_img('/Users/qigroup/mnt/sylvian/blast/data/derivatives/fsl/grouplevelanalysis/SSL_child_JOVE_3.09_masked.gfeat/cope2.feat/cluster_mask_zstat1.nii.gz', fwhm=6)
SSL_rand_result_img = smooth_img('/Users/qigroup/mnt/sylvian/blast/data/derivatives/fsl/grouplevelanalysis/SSL_child_JOVE_3.09_masked.gfeat/cope1.feat/cluster_mask_zstat1.nii.gz', fwhm=6)


#VSL_result_img = smooth_img('/Volumes/data/projects/blast/data/derivatives/fsl/higherlevelanalysis/sub-blastc210/VSL_norm.gfeat/cope1.feat/stats/zstat1.nii.gz', fwhm=6) 
#LSL_result_img = smooth_img('/Volumes/data/projects/blast/data/derivatives/fsl/higherlevelanalysis/sub-blastc210/VSL_norm.gfeat/cope2.feat/stats/zstat2.nii.gz', fwhm=6)

# %%
from nilearn import plotting

plotting.plot_glass_brain(SSL_struct_result_img, title='Speech Structure > Random',display_mode='lyrz', threshold = 'auto')
plotting.plot_glass_brain(SSL_rand_result_img, title='Speech Random > Structure', display_mode='lyrz', threshold = 'auto')


plotting.plot_glass_brain(TSL_struct_result_img, title='Tone Structure > Random', display_mode='lyrz', threshold = 'auto')
plotting.plot_glass_brain(TSL_rand_result_img, title='Tone Random > Structure', display_mode='lyrz', threshold = 'auto')

# %%
plotting.plot_glass_brain(SSL_struct_result_img, title='Speech Structure > Random', threshold = 3.09)
plotting.plot_glass_brain(SSL_rand_result_img, title='Speech Random > Structure', threshold = 3.09)


plotting.plot_glass_brain(TSL_struct_result_img, title='Tone Structure > Random', threshold = 3.09)
plotting.plot_glass_brain(TSL_rand_result_img, title='Tone Random > Structure', threshold = 3.09)

# %%
VSL_struct_result_img = smooth_img('/Users/qigroup/mnt/sylvian/blast/data/derivatives/fsl/grouplevelanalysis/VSL_child_JOVE_3.09_masked.gfeat/cope1.feat/cluster_mask_zstat1.nii.gz', fwhm=6)  
VSL_rand_result_img = smooth_img('/Users/qigroup/mnt/sylvian/blast/data/derivatives/fsl/grouplevelanalysis/VSL_child_JOVE_3.09_masked.gfeat/cope2.feat/cluster_mask_zstat1.nii.gz', fwhm=6)  


LSL_struct_result_img = smooth_img('/Users/qigroup/mnt/sylvian/blast/data/derivatives/fsl/grouplevelanalysis/LSL_child_JOVE_3.09_masked.gfeat/cope2.feat/cluster_mask_zstat1.nii.gz', fwhm=6)
LSL_rand_result_img = smooth_img('/Users/qigroup/mnt/sylvian/blast/data/derivatives/fsl/grouplevelanalysis/LSL_child_JOVE_3.09_masked.gfeat/cope1.feat/cluster_mask_zstat1.nii.gz', fwhm=6)

# %%
plotting.plot_glass_brain(VSL_struct_result_img, title='Image Structure > Random', display_mode='lyrz', threshold = 'auto')
plotting.plot_glass_brain(VSL_rand_result_img, title='Image Random > Structure', display_mode='lyrz', threshold = 'auto')


plotting.plot_glass_brain(LSL_struct_result_img, title='Letter Structure > Random', display_mode='lyrz', threshold = 'auto')
plotting.plot_glass_brain(LSL_rand_result_img, title='Letter Random > Structure', display_mode='lyrz', threshold = 'auto')

# %%
fsaverage = ('/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/lh.pial')

# %%
from nilearn import surface

texture = surface.vol_to_surf(SSL_struct_result_img, fsaverage)

# %%
from nilearn import plotting

plotting.plot_surf_stat_map('/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/lh.inflated', texture, hemi='left',
                            title='Surface left hemisphere', colorbar=True, threshold= 1., bg_map='/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/lh.sulc')

plotting.plot_surf_stat_map('/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/rh.inflated', texture, hemi='right',
                            title='Surface right hemisphere', colorbar=True, threshold= 1., bg_map='/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/rh.sulc')

# %%
TSL_texture = surface.vol_to_surf(TSL_struct_result_img, fsaverage)
plotting.plot_surf_stat_map('/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/lh.inflated', TSL_texture, hemi='left',
                            title='Surface left hemisphere', colorbar=True, threshold= 1., bg_map='/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/lh.sulc')

plotting.plot_surf_stat_map('/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/rh.inflated', TSL_texture, hemi='right',
                            title='Surface right hemisphere', colorbar=True, threshold= 1., bg_map='/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/rh.sulc')

# %%
VSL_struct_result_img = smooth_img('/Users/qigroup/mnt/sylvian/blast/data/derivatives/fsl/grouplevelanalysis/VSL_child_JOVE_3.09_masked.gfeat/cope1.feat/thresh_zstat1.nii.gz', fwhm=6)  

VSL_texture = surface.vol_to_surf(VSL_struct_result_img, fsaverage)
plotting.plot_surf_stat_map('/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/lh.inflated', VSL_texture, hemi='left',
                            title='Surface left hemisphere', colorbar=True, threshold= 2., bg_map='/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/lh.sulc')

plotting.plot_surf_stat_map('/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/rh.inflated', VSL_texture, hemi='right',
                            title='Surface right hemisphere', colorbar=True, threshold= 2., bg_map='/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/rh.sulc')
# Out:
# /Users/qigroup/.local/lib/python3.7/site-packages/nilearn/plotting/surf_plotting.py:256: RuntimeWarning: invalid value encountered in true_divide
#   surf_map_faces = surf_map_faces / (vmax - vmin)
# /Users/qigroup/anaconda3/lib/python3.7/site-packages/matplotlib/colorbar.py:614: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0.0, top=0.0
#   ax.set_ylim(*ax.dataLim.intervaly)
# /Users/qigroup/anaconda3/lib/python3.7/site-packages/matplotlib/colorbar.py:1042: RuntimeWarning: invalid value encountered in true_divide
#   z = np.take(y, i0) + (xn - np.take(b, i0)) * dy / db
# /Users/qigroup/.local/lib/python3.7/site-packages/nilearn/plotting/img_plotting.py:225: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0.0, top=0.0
#   cbar.ax.set_ylim(cbar.norm(cbar_vmin), cbar.norm(cbar_vmax))
# ...

# %%
LSL_texture = surface.vol_to_surf(LSL_struct_result_img, fsaverage)
plotting.plot_surf_stat_map('/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/lh.inflated', LSL_texture, hemi='left',
                            title='Surface left hemisphere', colorbar=True, threshold= 1., bg_map='/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/lh.sulc')

plotting.plot_surf_stat_map('/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/rh.inflated', LSL_texture, hemi='right',
                            title='Surface right hemisphere', colorbar=True, threshold= 1., bg_map='/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/rh.sulc')

# %%
plotting.plot_glass_brain(VSL_struct_result_img, display_mode='lr', plot_abs=False,
                          title='Glass brain', threshold=2.)

plotting.plot_stat_map(VSL_struct_result_img, display_mode='x', threshold=1.,
                       cut_coords=range(0, 51, 10), title='Slices')
plotting.plot_stat_map(VSL_struct_result_img, display_mode='y', threshold=1.,
                       cut_coords=range(0, 51, 10), title='Slices')
plotting.plot_stat_map(VSL_struct_result_img, display_mode='z', threshold=1.,
                       cut_coords=range(0, 51, 10), title='Slices')
# Out:
# /Users/qigroup/.local/lib/python3.7/site-packages/nilearn/plotting/displays.py:780: UserWarning: empty mask
#   get_mask_bounds(new_img_like(img, not_mask, affine))
